# %%
import pandas as pd
import numpy as np 
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import plotly.express as px
import seaborn as sns

# %%
# loading S&P500 Companies csv
file_path= Path('raw_data/sp500_companies.csv')
df = pd.read_csv(file_path)

# %%
# Following cells will be basic discovery on each of the three CSV's

df.head()
# Out:
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   AAPL             Apple Inc.             Apple Inc.
# 1      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 2      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 3      NMS   GOOG          Alphabet Inc.          Alphabet Inc.
# 4      NMS  GOOGL          Alphabet Inc.          Alphabet Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology            Consumer Electronics        226.51
# 1              Technology       Software - Infrastructure        424.80
# 2              Technology                  Semiconductors        127.25
# 3  Communication Services  Internet Content & Information        168.96
# 4  Communication Services  Internet Content & Information        167.18
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3443880624128  1.317810e+11          0.049      Cupertino    CA
# ...

# %%
df.describe()
# Out:
#        Currentprice     Marketcap        Ebitda  Revenuegrowth  \
# count    503.000000  5.030000e+02  4.740000e+02     501.000000
# mean     216.820636  1.033990e+11  6.769558e+09       0.059299
# std      481.429247  3.104124e+11  1.477534e+10       0.175231
# min        7.770000  6.226443e+09 -4.107000e+09      -0.573000
# 25%       66.960000  1.868221e+10  1.595674e+09      -0.003000
# 50%      119.940000  3.577275e+10  2.869578e+09       0.047000
# 75%      227.035000  7.426606e+10  5.874562e+09       0.096000
# max     8784.150000  3.443881e+12  1.317810e+11       2.621000
#
#        Fulltimeemployees      Weight
# count       4.940000e+02  503.000000
# mean        5.804538e+04    0.001988
# std         1.396222e+05    0.005968
# min         2.800000e+01    0.000120
# 25%         9.909500e+03    0.000359
# 50%         2.085000e+04    0.000688
# 75%         5.373650e+04    0.001428
# max         2.100000e+06    0.066216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Exchange             503 non-null    object
#  1   Symbol               503 non-null    object
#  2   Shortname            503 non-null    object
#  3   Longname             503 non-null    object
#  4   Sector               503 non-null    object
#  5   Industry             503 non-null    object
#  6   Currentprice         503 non-null    float64
#  7   Marketcap            503 non-null    int64
#  8   Ebitda               474 non-null    float64
#  9   Revenuegrowth        501 non-null    float64
#  10  City                 503 non-null    object
#  11  State                483 non-null    object
#  12  Country              503 non-null    object
#  13  Fulltimeemployees    494 non-null    float64
#  14  Longbusinesssummary  503 non-null    object
# ...

# %%
df.size
# Out:
# 8048

# %%
df.value_counts()
# Out:
# Exchange  Symbol  Shortname                       Longname                        Sector              Industry                                  Currentprice  Marketcap     Ebitda        Revenuegrowth  City              State  Country        Fulltimeemployees  Longbusinesssummary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               
# ...

# %%
df.isnull().sum()
# Out:
# Exchange                0
# Symbol                  0
# Shortname               0
# Longname                0
# Sector                  0
# Industry                0
# Currentprice            0
# Marketcap               0
# Ebitda                 29
# Revenuegrowth           2
# City                    0
# State                  20
# Country                 0
# Fulltimeemployees       9
# Longbusinesssummary     0
# Weight                  0
# dtype: int64

# %%
companies_df = df
companies_df.head(5)
# Out:
#   Exchange Symbol              Shortname               Longname  \
# 0      NMS   AAPL             Apple Inc.             Apple Inc.
# 1      NMS   MSFT  Microsoft Corporation  Microsoft Corporation
# 2      NMS   NVDA     NVIDIA Corporation     NVIDIA Corporation
# 3      NMS   GOOG          Alphabet Inc.          Alphabet Inc.
# 4      NMS  GOOGL          Alphabet Inc.          Alphabet Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology            Consumer Electronics        226.51
# 1              Technology       Software - Infrastructure        424.80
# 2              Technology                  Semiconductors        127.25
# 3  Communication Services  Internet Content & Information        168.96
# 4  Communication Services  Internet Content & Information        167.18
#
#        Marketcap        Ebitda  Revenuegrowth           City State  \
# 0  3443880624128  1.317810e+11          0.049      Cupertino    CA
# ...

# %%
#loading S&P 500 index csv

file_path = Path('raw_data/sp500_index.csv')
df = pd.read_csv(file_path)
df.head()
# Out:
#          Date   S&P500
# 0  2014-08-21  1992.37
# 1  2014-08-22  1988.40
# 2  2014-08-25  1997.92
# 3  2014-08-26  2000.02
# 4  2014-08-27  2000.12

# %%
df.describe()
# Out:
#             S&P500
# count  2516.000000
# mean   3216.643247
# std     999.630102
# min    1829.080000
# 25%    2338.022500
# 50%    2914.020000
# 75%    4123.525000
# max    5667.200000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2516 entries, 0 to 2515
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2516 non-null   object
#  1   S&P500  2516 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 39.4+ KB

# %%
df.value_counts()
# Out:
# Date        S&P500
# 2014-08-21  1992.37    1
# 2021-04-27  4186.72    1
# 2021-04-16  4185.47    1
# 2021-04-19  4163.26    1
# 2021-04-20  4134.94    1
#                       ..
# 2017-12-18  2690.16    1
# 2017-12-19  2681.47    1
# 2017-12-20  2679.25    1
# 2017-12-21  2684.57    1
# 2024-08-20  5597.12    1
# Length: 2516, dtype: int64

# %%
df.isnull().sum()
# Out:
# Date      0
# S&P500    0
# dtype: int64

# %%
index_df = df

# %%
fig = px.line(index_df,x=index_df['Date'],y=index_df['S&P500'],title='Performance Over Time')
ax.plot(index_df['Date'],index_df['S&P500'])
fig.update_xaxes(rangeslider_visible=False,
                 rangeselector=dict(
                     buttons=list([
                         dict(count=6, label="6m", step="month", stepmode="backward"),
                         dict(count=1, label="1y", step="year", stepmode="backward"),
                         dict(count=2, label="2y", step="year", stepmode="backward"),
                         dict(step="all")])),
                 row=1,col=1)
ax.set(xlabel = 'Date', ylabel = 'Index')
ax.grid()
fig.show()

# %%
#loading stocks csv

file_path = Path('raw_data/sp500_stocks.csv')
df= pd.read_csv(file_path)
df.head(20)
# Out:
#           Date Symbol  Adj Close      Close       High        Low       Open  \
# 0   2010-01-04    MMM  44.254017  69.414719  69.774246  69.122070  69.473244
# 1   2010-01-05    MMM  43.976837  68.979935  69.590302  68.311035  69.230766
# 2   2010-01-06    MMM  44.600502  69.958191  70.735786  69.824417  70.133781
# 3   2010-01-07    MMM  44.632484  70.008362  70.033447  68.662209  69.665550
# 4   2010-01-08    MMM  44.946964  70.501671  70.501671  69.648827  69.974915
# 5   2010-01-11    MMM  44.765736  70.217392  70.735786  69.740807  70.551842
# 6   2010-01-12    MMM  44.803055  70.275917  70.384613  69.648827  69.882942
# 7   2010-01-13    MMM  44.659130  70.050163  70.326088  69.565216  70.326088
# 8   2010-01-14    MMM  44.509876  69.816055  70.175583  69.749161  70.016724
# 9   2010-01-15    MMM  44.440594  69.707359  70.309364  69.289299  69.832779
# 10  2010-01-19    MMM  45.373432  71.170570  71.212372  69.816055  70.083611
# ...

# %%
df.describe()
# Out:
#           Adj Close         Close          High           Low          Open  \
# count  1.757167e+06  1.757167e+06  1.757167e+06  1.757167e+06  1.757167e+06
# mean   9.618659e+01  1.037039e+02  1.048399e+02  1.025118e+02  1.036839e+02
# std    2.054719e+02  2.056383e+02  2.080360e+02  2.031662e+02  2.055534e+02
# min    2.036244e-01  2.220000e-01  2.262500e-01  2.162500e-01  2.180000e-01
# 25%    2.890313e+01  3.485000e+01  3.523000e+01  3.445000e+01  3.485000e+01
# 50%    5.341603e+01  6.228000e+01  6.291000e+01  6.160000e+01  6.226000e+01
# 75%    1.024300e+02  1.126400e+02  1.138000e+02  1.114100e+02  1.126200e+02
# max    8.854820e+03  8.854820e+03  8.944000e+03  8.766080e+03  8.874990e+03
#
#              Volume
# count  1.757167e+06
# mean   6.966618e+06
# std    3.318610e+07
# min    0.000000e+00
# 25%    9.990000e+05
# 50%    2.179856e+06
# 75%    5.000000e+06
# max    3.692928e+09

# %%
df.size
# Out:
# 14816368

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1852046 entries, 0 to 1852045
# Data columns (total 8 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Date       object
#  1   Symbol     object
#  2   Adj Close  float64
#  3   Close      float64
#  4   High       float64
#  5   Low        float64
#  6   Open       float64
#  7   Volume     float64
# dtypes: float64(6), object(2)
# memory usage: 113.0+ MB

# %%
df.value_counts()
# Out:
# Date        Symbol  Adj Close   Close       High        Low         Open        Volume
# 2010-01-04  A       20.084951   22.389128   22.625179   22.267525   22.453505   3815561.0     1
# 2019-12-13  AVB     176.717590  208.639999  210.830002  206.289993  209.330002  599100.0      1
#             ARE     134.358871  156.470001  158.259995  155.419998  157.039993  696600.0      1
#             APTV    93.312675   93.550003   96.360001   93.309998   95.620003   1227900.0     1
#             APH     25.570942   26.785000   27.075001   26.735001   26.959999   4476000.0     1
#                                                                                              ..
# 2015-02-20  WST     51.565048   53.750000   54.070000   53.110001   53.730000   618100.0      1
#             WRB     10.807263   14.957037   14.957037   14.764444   14.800000   1561275.0     1
#             WMT     23.055832   28.100000   28.126667   27.516666   27.576668   41521200.0    1
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# Symbol           0
# Adj Close    94879
# Close        94879
# High         94879
# Low          94879
# Open         94879
# Volume       94879
# dtype: int64
